# %%
import pandas as pd

# %%
from utils.evaluation import Evaluator
# Out:
# C:\Users\User\anaconda3\envs\stable_diff\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: Could not find module 'C:\Users\User\anaconda3\envs\stable_diff\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")

# %%
result_folder = "C:/Users/User/Desktop/Career Building/cvs/semester_project/euler_script/euler_results/"

result_file ="depth_prompt_Intri_iter_40_guide_9.csv"

df = pd.read_csv(result_folder + result_file, names=Evaluator.columns)
clean_df = df

# %%
clean_df
# Out:
#         id     LPIPS  CLIPScore  GR-Abs-Rel  GR-Sqr-Rel   GR-RMSE  \
# 0      0.0  0.738223  28.766800    0.060219    0.015800  0.212116
# 1      1.0  0.737466  27.687450    0.090171    0.024138  0.219953
# 2      2.0  0.657221  27.469540    0.070545    0.015629  0.165637
# 3      3.0  0.654286  28.918880    0.086378    0.027314  0.235687
# 4      4.0  0.731663  25.289667    0.100362    0.043074  0.366991
# ..     ...       ...        ...         ...         ...       ...
# 206  206.0  0.707271  30.713028    0.135390    0.161430  0.901667
# 207  207.0  0.717560  28.229486    0.193094    0.159106  0.652130
# 208  208.0  0.741836  27.477726    0.078948    0.020028  0.206631
# 209  209.0  0.703706  25.643852    0.183576    0.227690  0.964991
# 210  210.0  0.690875  24.672169    0.182434    0.169884  0.753411
#
#      GR-RMSE-log  GR-thresh-1  GR-thresh-2  GR-thresh-3  ...  \
# 0       0.075733     0.999029     1.000000     1.000000  ...
# ...

# %%
macro_result_file =  "macro_eval_metrics.csv" 

macro_df = pd.read_csv(result_folder + macro_result_file, names=['identifier', 'FID', 'IS_mean', 'IS_std'])

# %%
clean_df.std()
# Out:
# id                   6.105462e+01
# LPIPS                2.968093e-02
# CLIPScore            2.854055e+00
# GR-Abs-Rel           2.838900e+00
# GR-Sqr-Rel           1.735166e+08
# GR-RMSE              1.206464e+04
# GR-RMSE-log          9.027513e-02
# GR-thresh-1          2.281465e-01
# GR-thresh-2          1.139421e-01
# GR-thresh-3          5.868490e-02
# Pred-GR-Abs-Rel      2.379755e-01
# Pred-GR-Sqr-Rel      9.395140e+05
# Pred-GR-RMSE         1.215937e+04
# Pred-GR-RMSE-log     1.343718e-01
# Pred-GR-thresh-1     2.182487e-01
# Pred-GR-thresh-2     1.166332e-01
# Pred-GR-thresh-3     6.483922e-02
# Pred-Gen-Abs-Rel     6.833704e-01
# Pred-Gen-Sqr-Rel     5.171543e+06
# Pred-Gen-RMSE        1.663775e+03
# Pred-Gen-RMSE-log    1.596452e-01
# Pred-Gen-thresh-1    2.470439e-01
# Pred-Gen-thresh-2    1.750047e-01
# Pred-Gen-thresh-3    1.114652e-01
# dtype: float64

# %%
clean_df.mean()
# Out:
# id                   1.050000e+02
# LPIPS                7.108345e-01
# CLIPScore            2.730951e+01
# GR-Abs-Rel           6.815471e-01
# GR-Sqr-Rel           1.747503e+07
# GR-RMSE              1.547301e+03
# GR-RMSE-log          1.621332e-01
# GR-thresh-1          7.777855e-01
# GR-thresh-2          9.311934e-01
# GR-thresh-3          9.730437e-01
# Pred-GR-Abs-Rel      2.246165e-01
# Pred-GR-Sqr-Rel      8.440951e+04
# Pred-GR-RMSE         1.701570e+03
# Pred-GR-RMSE-log     2.160511e-01
# Pred-GR-thresh-1     7.316313e-01
# Pred-GR-thresh-2     9.082310e-01
# Pred-GR-thresh-3     9.593184e-01
# Pred-Gen-Abs-Rel     3.358264e-01
# Pred-Gen-Sqr-Rel     3.906462e+05
# Pred-Gen-RMSE        1.730595e+02
# Pred-Gen-RMSE-log    2.682925e-01
# Pred-Gen-thresh-1    6.313694e-01
# Pred-Gen-thresh-2    8.611717e-01
# Pred-Gen-thresh-3    9.426456e-01
# dtype: float64

# %%
clean_df.size
# Out:
# 2640
