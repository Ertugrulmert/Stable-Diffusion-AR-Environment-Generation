# %%
import pandas as pd

# %%
from utils.evaluation import Evaluator

# %%
result_folder = "C:/Users/User/Desktop/Career Building/cvs/semester_project/euler_script/euler_results/"

result_file = "depth_prompt_Intri_iter_40_guide_9.csv.csv"

df = pd.read_csv(result_folder + result_file, names=Evaluator.columns)
clean_df = df.iloc[6:]

# %%
clean_df
# Out:
#         id     LPIPS  CLIPScore  GR-Abs-Rel     GR-Sqr-Rel      GR-RMSE  \
# 6      0.0  0.738223  28.766800    0.060219       0.015800     0.212116
# 7      1.0  0.737466  27.687450    0.090171       0.024138     0.219953
# 8      2.0  0.657221  27.469540    0.070545       0.015629     0.165637
# 9      3.0  0.654286  28.918880    0.086378       0.027314     0.235687
# 10     4.0  0.731663  25.289667    0.100362       0.043074     0.366991
# ..     ...       ...        ...         ...            ...          ...
# 111  105.0  0.729674  29.572279    0.671520    4125.607422   188.155258
# 112  106.0  0.714000  27.980793    0.929117  139593.500000  1105.695557
# 113  107.0  0.733336  28.329548    0.963818    9059.272461   267.584747
# 114  108.0  0.725066  22.573837    2.005075  465936.718750  1875.666504
# 115  109.0  0.709847  27.905270    1.123559   34857.210938   570.629944
#
#      GR-RMSE-log  GR-thresh-1  GR-thresh-2  GR-thresh-3  ...  \
# 6       0.075733     0.999029     1.000000     1.000000  ...
# 7       0.115736     0.949435     1.000000     1.000000  ...
# 8       0.093103     0.970284     0.999950     1.000000  ...
# 9       0.121211     0.934326     0.993677     0.999687  ...
# 10      0.120081     0.963831     0.997442     0.999992  ...
# ..           ...          ...          ...          ...  ...
# 111          NaN     0.150732     0.560666     0.814689  ...
# 112          NaN     0.588942     0.924635     0.978435  ...
# 113          NaN     0.288150     0.486822     0.616713  ...
# 114          NaN     0.322121     0.475797     0.703608  ...
# 115          NaN     0.517506     0.750630     0.917644  ...
#
#      Pred-GR-thresh-1  Pred-GR-thresh-2  Pred-GR-thresh-3  Pred-Gen-Abs-Rel  \
# 6            0.999029          1.000000          1.000000          0.060219
# 7            0.949435          1.000000          1.000000          0.090171
# 8            0.970284          0.999950          1.000000          0.070545
# 9            0.934326          0.993677          0.999687          0.086378
# 10           0.963831          0.997442          0.999992          0.100362
# ..                ...               ...               ...               ...
# 111          0.150732          0.560666          0.814689          0.671520
# 112          0.588942          0.924635          0.978435          0.929117
# 113          0.288150          0.486822          0.616713          0.963818
# 114          0.322121          0.475797          0.703608          2.005075
# 115          0.517506          0.750630          0.917644          1.123559
#
#      Pred-Gen-Sqr-Rel  Pred-Gen-RMSE  Pred-Gen-RMSE-log  Pred-Gen-thresh-1  \
# 6            0.015800       0.212116           0.075733           0.999029
# 7            0.024138       0.219953           0.115736           0.949435
# 8            0.015629       0.165637           0.093103           0.970284
# 9            0.027314       0.235687           0.121211           0.934326
# 10           0.043074       0.366991           0.120081           0.963831
# ..                ...            ...                ...                ...
# 111       4125.607422     188.155258                NaN           0.150732
# 112     139593.500000    1105.695557                NaN           0.588942
# 113       9059.272461     267.584747                NaN           0.288150
# 114     465936.718750    1875.666504                NaN           0.322121
# 115      34857.210938     570.629944                NaN           0.517506
#
#      Pred-Gen-thresh-2  Pred-Gen-thresh-3
# 6             1.000000           1.000000
# 7             1.000000           1.000000
# 8             0.999950           1.000000
# 9             0.993677           0.999687
# 10            0.997442           0.999992
# ..                 ...                ...
# 111           0.560666           0.814689
# 112           0.924635           0.978435
# 113           0.486822           0.616713
# 114           0.475797           0.703608
# 115           0.750630           0.917644
#
# [110 rows x 24 columns]

# %%
clean_df.std()
# Out:
# id                   3.189828e+01
# LPIPS                2.752451e-02
# CLIPScore            2.755492e+00
# GR-Abs-Rel           3.871793e+00
# GR-Sqr-Rel           2.397246e+08
# GR-RMSE              1.662711e+04
# GR-RMSE-log          1.002935e-01
# GR-thresh-1          2.368366e-01
# GR-thresh-2          1.344389e-01
# GR-thresh-3          7.422199e-02
# Pred-GR-Abs-Rel      3.871793e+00
# Pred-GR-Sqr-Rel      2.397246e+08
# Pred-GR-RMSE         1.662711e+04
# Pred-GR-RMSE-log     1.002935e-01
# Pred-GR-thresh-1     2.368366e-01
# Pred-GR-thresh-2     1.344389e-01
# Pred-GR-thresh-3     7.422199e-02
# Pred-Gen-Abs-Rel     3.871793e+00
# Pred-Gen-Sqr-Rel     2.397246e+08
# Pred-Gen-RMSE        1.662711e+04
# Pred-Gen-RMSE-log    1.002935e-01
# Pred-Gen-thresh-1    2.368366e-01
# Pred-Gen-thresh-2    1.344389e-01
# Pred-Gen-thresh-3    7.422199e-02
# dtype: float64

# %%
clean_df.mean()
# Out:
# id                   5.450000e+01
# LPIPS                7.065498e-01
# CLIPScore            2.712518e+01
# GR-Abs-Rel           1.050317e+00
# GR-Sqr-Rel           3.344993e+07
# GR-RMSE              2.850979e+03
# GR-RMSE-log          1.591975e-01
# GR-thresh-1          7.645096e-01
# GR-thresh-2          9.145339e-01
# GR-thresh-3          9.632405e-01
# Pred-GR-Abs-Rel      1.050317e+00
# Pred-GR-Sqr-Rel      3.344993e+07
# Pred-GR-RMSE         2.850979e+03
# Pred-GR-RMSE-log     1.591975e-01
# Pred-GR-thresh-1     7.645096e-01
# Pred-GR-thresh-2     9.145339e-01
# Pred-GR-thresh-3     9.632405e-01
# Pred-Gen-Abs-Rel     1.050317e+00
# Pred-Gen-Sqr-Rel     3.344993e+07
# Pred-Gen-RMSE        2.850979e+03
# Pred-Gen-RMSE-log    1.591975e-01
# Pred-Gen-thresh-1    7.645096e-01
# Pred-Gen-thresh-2    9.145339e-01
# Pred-Gen-thresh-3    9.632405e-01
# dtype: float64

# %%
clean_df.size
# Out:
# 2640
